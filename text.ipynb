# %% [markdown]
# <h1>1212</h1>
#
# #1 #23
# ## 12
# ###### 12
# ㅁㄴ
#
# **aa**
# *a*
# _a_
# a
# _11_
# 11
# *11*
# print(11)
# `print(11)`
# ~~11~~
# > aa
# >> aa
# * 111
# -aa
# -    aa
# [naver](http://www.naver.com/)
# ![한빛](http://www.hanbit.co.kr/images/common/logo_hanbit.png);
# $y = x \times z$
# $y = x \times z$
# $y = x \times z$
#
# d
# $\times$ d
# ㅁ
# ㅁ  ㅁ
# ㅁ  ㅁ

# %%
print('1')
# Out:
# 1
# 2
# 3
# 3
# 3
# 3
